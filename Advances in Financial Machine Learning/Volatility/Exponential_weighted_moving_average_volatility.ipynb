# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from FinancialMachineLearning.features.volatility import daily_volatility

# %%
import os
os.chdir('..')
os.chdir('..')
os.getcwd()
# Out:
# '/Users/junghunlee/Desktop/Pycharm/FinancialMachineLearning'

# %%
dollar = pd.read_csv('./Data/dollar_IVEfuture.csv', index_col = 0, parse_dates = True)
dollar = dollar[~dollar.index.duplicated(keep = 'first')]

# %% [markdown]
# #### EWMA Volatility

# %%
ewma_vol = daily_volatility(dollar.close, lookback = 50)

# %%
ewma_vol.plot(figsize = (10,4), grid = False)
plt.title('Extimated Volatility with EWMA', fontsize = 12, fontfamily = 'Serif')
plt.xlabel(r'$\tau$')
plt.ylabel(r'$\sigma$')
# Out:
# Text(0, 0.5, '$\\sigma$')
