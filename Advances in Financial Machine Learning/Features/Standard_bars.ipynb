# %%
from FinancialMachineLearning.barsampling.core import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.chdir('..')
os.chdir('..')
os.getcwd()
# Out:
# '/Users/junghunlee/Desktop/Pycharm/FinancialMachineLearning'

# %% [markdown]
# #### Bar Samplizing

# %% [markdown]
# txt파일형식의 고빈도데이터를 csv파일 형태로 저장해두자

# %%
#data = pd.read_csv('./Data/IVEfuture.txt')
#date_time = data['Date'] + ' ' + data['time'] 
#new_data = pd.concat([date_time, data['price'], data['volume']], axis = 1)
#new_data.columns = ['date', 'price', 'volume']
#new_data.to_csv('./Data/IVEfuture.csv', index = False)

# %%
bar = StandardBarFeatures(file_path_or_df = './Data/IVEfuture.csv')

# %% [markdown]
# #### Tick Bar

# %%
tick = bar.tick_bar(threshold = 600)
tick
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Batch number: 2
# Batch number: 3
# Batch number: 4
# Batch number: 5
# Batch number: 6
# Batch number: 7
# Batch number: 8
# Batch number: 9
# Batch number: 10
# Returning bars
#                 date_time  tick_num      open     high       low   close  \
# 0     2009-09-28 10:24:04       600   50.7900   51.290   50.7100   51.25
# 1     2009-09-28 11:51:42      1200   51.2500   51.436   51.2300   51.43
# 2     2009-09-28 14:09:28      1800   51.4300   51.600   51.4060   51.44
# 3     2009-09-28 15:09:12      2400   51.4400   51.530   51.3936   51.43
# 4     2009-09-29 10:03:18      3000   51.4300   51.960   51.3790   51.52
# ...                   ...       ...       ...      ...       ...     ...
# 18212 2023-09-12 14:16:16  10927800  161.8201  162.270  161.2600  161.79
# 18213 2023-09-13 11:19:11  10928400  161.8100  161.852  160.5000  161.74
# 18214 2023-09-13 15:54:09  10929000  161.6126  161.820  160.8300  161.24
# 18215 2023-09-14 11:50:59  10929600  161.2300  162.740  161.2100  162.67
# 18216 2023-09-14 15:59:51  10930200  162.6700  163.215  162.6600  162.99
#
#        volume  cum_buy_volume  cum_ticks  cum_dollar_value
# 0      191164          130023        600      9.780588e+06
# 1      176724           98400        600      9.072843e+06
# 2      157179           89990        600      8.090282e+06
# 3      205400           69674        600      1.056945e+07
# 4      149219           86863        600      7.700035e+06
# ...       ...             ...        ...               ...
# 18212  113011           55164        600      1.827083e+07
# 18213  105906           54178        600      1.709234e+07
# 18214  128158           68577        600      2.068534e+07
# 18215  288923           88439        600      4.672396e+07
# 18216  152485           86905        600      2.485028e+07
#
# [18217 rows x 10 columns]

# %%
tick.to_csv('./Data/tick_IVEfuture.csv', index = False)

# %% [markdown]
# #### Volume Bar

# %%
volume = bar.volume_bar(threshold = 10000)
volume
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Batch number: 2
# Batch number: 3
# Batch number: 4
# Batch number: 5
# Batch number: 6
# Batch number: 7
# Batch number: 8
# Batch number: 9
# Batch number: 10
# Returning bars
#                  date_time  tick_num      open    high       low     close  \
# 0      2009-09-28 09:41:53        48   50.7900   50.85   50.7100   50.8400
# 1      2009-09-28 09:46:35        81   50.8500   51.07   50.8300   51.0700
# 2      2009-09-28 09:47:25       106   51.0700   51.07   51.0500   51.0600
# 3      2009-09-28 09:53:47       148   51.0600   51.15   51.0600   51.1300
# 4      2009-09-28 09:54:34       180   51.1300   51.14   51.1300   51.1300
# ...                    ...       ...       ...     ...       ...       ...
# 223576 2023-09-14 15:40:33  10930025  162.9800  163.01  162.9600  162.9801
# 223577 2023-09-14 15:54:09  10930080  162.9701  163.06  162.9654  162.9800
# 223578 2023-09-14 15:59:28  10930153  162.9700  163.05  162.9299  163.0400
# 223579 2023-09-14 15:59:59  10930209  163.0300  163.03  162.9700  162.9800
# 223580 2023-09-14 16:00:00  10930213  162.9700  163.00  162.9700  162.9700
#
#         volume  cum_buy_volume  cum_ticks  cum_dollar_value
# 0        10144            5364         48      5.152712e+05
# 1        11900            9900         33      6.068960e+05
# 2        10000            9900         25      5.106420e+05
# 3        10824            8174         42      5.532435e+05
# 4        10851            4451         32      5.548561e+05
# ...        ...             ...        ...               ...
# 223576   10090            8890         20      1.644557e+06
# 223577   10043            4899         55      1.637132e+06
# 223578   10057            6528         73      1.639379e+06
# 223579   10051            3612         56      1.638215e+06
# 223580   32157             335          4      5.240636e+06
#
# [223581 rows x 10 columns]

# %%
volume.to_csv('./Data/volume_IVEfuture.csv', index = False)

# %% [markdown]
# #### Dollar Value Bar

# %%
dollar = bar.dollar_bar()
dollar
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Batch number: 2
# Batch number: 3
# Batch number: 4
# Batch number: 5
# Batch number: 6
# Batch number: 7
# Batch number: 8
# Batch number: 9
# Batch number: 10
# Returning bars
#                  date_time  tick_num    open     high       low   close  \
# 0      2009-09-28 09:46:34        80   50.79   51.070   50.7100   51.07
# 1      2009-09-28 09:52:47       142   51.07   51.148   51.0500   51.13
# 2      2009-09-28 09:54:38       201   51.14   51.150   51.1290   51.13
# 3      2009-09-28 09:55:26       243   51.13   51.150   51.1300   51.14
# 4      2009-09-28 10:02:48       339   51.14   51.260   51.0800   51.25
# ...                    ...       ...     ...      ...       ...     ...
# 226209 2023-09-14 15:54:32  10930083  162.98  163.060  162.9654  162.98
# 226210 2023-09-14 15:59:20  10930131  162.99  163.040  162.9299  163.04
# 226211 2023-09-14 15:59:39  10930171  163.04  163.050  162.9900  163.00
# 226212 2023-09-14 15:59:59  10930208  162.99  163.000  162.9700  162.98
# 226213 2023-09-14 16:00:00  10930213  162.98  163.000  162.9700  162.97
#
#         volume  cum_buy_volume  cum_ticks  cum_dollar_value
# 0        20044           13264         80      1.020027e+06
# 1        21024           19774         62      1.073986e+06
# 2        19951            6951         59      1.020145e+06
# 3        19652           18052         42      1.004999e+06
# 4        19943           11354         96      1.020512e+06
# ...        ...             ...        ...               ...
# 226209    6186            3983         39      1.008408e+06
# 226210    7158            4629         48      1.166735e+06
# 226211    6316            3266         40      1.029639e+06
# 226212    6234            2145         37      1.016030e+06
# 226213   32257             335          5      5.256934e+06
#
# [226214 rows x 10 columns]

# %%
dollar.to_csv('./Data/dollar_IVEfuture.csv', index = False)

# %% [markdown]
# #### Bar Counting

# %%
data = pd.read_csv('./Data/IVEfuture.csv', index_col=0, parse_dates=True)
dollar = pd.read_csv('./Data/dollar_IVEfuture.csv', index_col=0, parse_dates=True)
volume = pd.read_csv('./Data/volume_IVEfuture.csv', index_col=0, parse_dates=True)
tick = pd.read_csv('./Data/tick_IVEfuture.csv', index_col=0, parse_dates=True)

# %%
time_count = data['price'].resample('W', label = 'right').count()
tick_count = tick['close'].resample('W', label = 'right').count()
volume_count = volume['close'].resample('W', label = 'right').count()
dollar_count = dollar['close'].resample('W', label = 'right').count()

# %%
count_df = pd.concat([time_count, tick_count, volume_count, dollar_count], axis = 1)
count_df.columns = ['time', 'tick', 'volume', 'dollar']
count_df
# Out:
#              time  tick  volume  dollar
# 2009-10-04  14151    23     318     165
# 2009-10-11   8792    15     196     103
# 2009-10-18   9727    16     200     106
# 2009-10-25  12453    21     249     133
# 2009-11-01  13525    22     303     155
# ...           ...   ...     ...     ...
# 2023-08-20   9435    16     143     222
# 2023-08-27  14613    24     213     332
# 2023-09-03   6432    11     118     184
# 2023-09-10   6035    10     130     192
# 2023-09-17   4031     7      78     120
#
# [729 rows x 4 columns]

# %%
count_df.iloc[:,1:].rolling(window = 10).mean().plot(figsize = (10,4))
plt.title('Bar Count', fontfamily = 'Serif', fontsize = 12)
plt.grid(False)

# %% [markdown]
# #### Sample Sationarity

# %%
time_returns = np.log(data['price']).diff().dropna()
tick_returns = np.log(tick['close']).diff().dropna()
volume_returns = np.log(volume['close']).diff().dropna()
dollar_returns = np.log(dollar['close']).diff().dropna()

# %%
time_standard = (time_returns - time_returns.mean()) / time_returns.std()
tick_standard = (tick_returns - tick_returns.mean()) / tick_returns.std()
volume_standard = (volume_returns - volume_returns.mean()) / volume_returns.std()
dollar_standard = (dollar_returns - dollar_returns.mean()) / dollar_returns.std()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize = (10,4))
sns.kdeplot(time_standard, label = "Time", ax = ax)
sns.kdeplot(tick_standard, label = "Tick", ax = ax)
sns.kdeplot(volume_standard, label = "Volume", ax = ax)
sns.kdeplot(dollar_standard, label = "Dollar Value", ax = ax)
sns.kdeplot(np.random.normal(size=1000000), label = "Normal distribution", 
            color = 'black', linestyle = "--", ax = ax)
plt.legend()
plt.grid(False)
plt.xlim(-5, 5)
plt.title('Distribution of sampled bars', fontfamily = 'Serif', fontsize = 12)
plt.show()
