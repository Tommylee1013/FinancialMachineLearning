# %%
from FinancialMachineLearning.barsampling.core import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.chdir('..')
os.chdir('..')
os.getcwd()
# Out:
# '/Users/junghunlee/Desktop/Pycharm/FinancialMachineLearning'

# %%
bar = RunBarFeatures('./Data/IVEfuture.csv')

# %% [markdown]
# #### Tick run bar

# %%
tick_run,_ = bar.const_tick_run_bar(expected_imbalance_window = 300, exp_num_ticks_init = 300)
tick_run
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#                 date_time  tick_num      open     high       low   close  \
# 0     2009-09-28 10:33:32       713   50.7900   51.380   50.7100   51.34
# 1     2009-09-28 11:22:56      1002   51.3400   51.370   51.2700   51.35
# 2     2009-09-28 12:04:34      1260   51.3500   51.440   51.3200   51.44
# 3     2009-09-28 13:47:21      1648   51.4400   51.600   51.4104   51.57
# 4     2009-09-28 14:18:08      1984   51.5700   51.570   51.4100   51.44
# ...                   ...       ...       ...      ...       ...     ...
# 37119 2023-09-13 15:50:38  10928967  161.4071  161.480  160.8300  161.18
# 37120 2023-09-14 10:12:19  10929278  161.2200  162.500  161.1700  162.17
# 37121 2023-09-14 11:44:23  10929559  162.1400  162.740  162.0700  162.57
# 37122 2023-09-14 14:44:34  10929881  162.5700  163.090  162.5400  163.06
# 37123 2023-09-14 15:59:45  10930174  163.0879  163.215  162.8900  162.97
#
# ...

# %%
plt.figure(figsize = (10, 4))
plt.scatter(tick_run['date_time'], tick_run.close, marker = '.', s = 1, edgecolor = 'none')
plt.grid(False)
plt.title('Tick Run Bar')
plt.show()

# %% [markdown]
# #### Volume run bar

# %%
volume_run,_ = bar.const_volume_run_bar(expected_imbalance_window = 300, exp_num_ticks_init = 100)
volume_run
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#                 date_time  tick_num     open      high       low   close  \
# 0     2009-09-28 09:55:26       255   50.790   51.1500   50.7100   51.14
# 1     2009-09-28 10:02:52       372   51.140   51.2600   51.0800   51.26
# 2     2009-09-28 10:14:10       475   51.259   51.2900   51.1900   51.26
# 3     2009-09-28 10:30:22       649   51.260   51.2900   51.1873   51.29
# 4     2009-09-28 10:45:01       801   51.290   51.3800   51.2800   51.33
# ...                   ...       ...      ...       ...       ...     ...
# 99005 2023-09-13 16:00:00  10929102  161.380  161.3819  161.2800  161.30
# 99006 2023-09-13 16:34:57  10929103  161.290  161.2900  161.2900  161.29
# 99007 2023-09-14 15:36:28  10930005  161.610  163.2150  161.6100  162.99
# 99008 2023-09-14 15:59:16  10930128  162.980  163.0600  162.9299  163.04
# 99009 2023-09-14 16:00:00  10930213  163.030  163.0500  162.9700  162.97
#
# ...

# %%
plt.figure(figsize = (10, 4))
plt.scatter(volume_run['date_time'], volume_run.close, marker = '.', s = 1, edgecolor = 'none')
plt.grid(False)
plt.title('Volume Run Bar')
plt.show()

# %% [markdown]
# #### Dollar run bar

# %%
dollar_run,_ = bar.const_dollar_run_bar(expected_imbalance_window = 300, exp_num_ticks_init = 100)
dollar_run
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#                 date_time  tick_num     open      high       low   close  \
# 0     2009-09-28 09:55:26       255   50.790   51.1500   50.7100   51.14
# 1     2009-09-28 10:02:52       372   51.140   51.2600   51.0800   51.26
# 2     2009-09-28 10:14:10       475   51.259   51.2900   51.1900   51.26
# 3     2009-09-28 10:30:22       649   51.260   51.2900   51.1873   51.29
# 4     2009-09-28 10:45:01       801   51.290   51.3800   51.2800   51.33
# ...                   ...       ...      ...       ...       ...     ...
# 98942 2023-09-13 16:00:00  10929102  161.380  161.3819  161.2800  161.30
# 98943 2023-09-13 16:34:57  10929103  161.290  161.2900  161.2900  161.29
# 98944 2023-09-14 15:36:28  10930005  161.610  163.2150  161.6100  162.99
# 98945 2023-09-14 15:59:16  10930128  162.980  163.0600  162.9299  163.04
# 98946 2023-09-14 16:00:00  10930213  163.030  163.0500  162.9700  162.97
#
# ...

# %%
plt.figure(figsize = (10, 4))
plt.scatter(dollar_run['date_time'], dollar_run.close, marker = '.', s = 1, edgecolor = 'none')
plt.grid(False)
plt.title('Dollar Run Bar')
plt.show()
