# %% [markdown]
# ### Bull-Bear Market Research

# %%
import yfinance as yf

start = '2010-01-01'
end = '2024-03-02'
ticker = 'AAPL'
data = yf.download(ticker, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data['Buy Pressure'] = (data['High'] - data['Open']) / data['Open']
data['Sell Pressure'] = (data['Open'] - data['Low']) / data['Open']

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.470741
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.481928
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.378825
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.367033
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.409363
# ...                ...         ...         ...         ...         ...
# 2024-02-26  182.240005  182.759995  180.649994  181.160004  181.160004
# 2024-02-27  181.100006  183.919998  179.559998  182.630005  182.630005
# 2024-02-28  182.509995  183.119995  180.130005  181.419998  181.419998
# 2024-02-29  181.270004  182.570007  179.529999  180.750000  180.750000
# 2024-03-01  179.550003  180.529999  177.380005  179.660004  179.660004
#
#                Volume  Buy Pressure  Sell Pressure
# Date
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(
    data['Buy Pressure'], 
    bins = 100, 
    edgecolor = 'none'
)
plt.hist(
    data['Sell Pressure'], 
    bins = 100, 
    edgecolor = 'none',
    alpha = 0.5
)
plt.grid(False)
plt.show()

# %%
plt.hist(data['Buy Pressure'] - data['Sell Pressure'], bins = 100, edgecolor = 'none')
plt.grid(False)
plt.show()

# %%
plt.plot((data['Buy Pressure'] - data['Sell Pressure']) * data['Volume'])
plt.grid(False)
plt.show()

# %%
plt.hist((data['Buy Pressure'] - data['Sell Pressure']) * data['Volume'], bins = 10000, edgecolor = 'none')
plt.grid(False)
plt.show()
