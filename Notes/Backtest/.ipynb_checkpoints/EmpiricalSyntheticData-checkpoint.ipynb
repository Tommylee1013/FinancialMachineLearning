# %% [markdown]
# ### Backtesting on synthetic simulation using empirical data

# %%
import numpy as np
import pandas as pd
from FinancialMachineLearning.backtest.backtest_synthetic_data import *
import yfinance as yf

start_date = '2020-01-01'
end_date = '2024-01-01'

apple = yf.download('AAPL', start = start_date, end = end_date)
apple.Close.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2020-01-02    75.087502
# 2020-01-03    74.357498
# 2020-01-06    74.949997
# 2020-01-07    74.597504
# 2020-01-08    75.797501
# Name: Close, dtype: float64

# %%
params = get_OU_params(apple.Close)

# %%
print(f"expected phi : {params['phi'] : .4f}")
print(f"expected forecast : {params['forecast'] : .4f}")
print(f"sigma : {params['sigma'] : .4f}")
print(f"half life : {params['half life'] : .4f}")
# Out:
# expected phi :  0.9955
# expected forecast :  4.9146
# sigma :  0.0211
# half life :  152.9182

# %%
rPT = rSLm = np.linspace(0, 10, 21)
coeffs = {'forecast' : params['forecast'], 'hl' : params['half life'], 'sigma' : 1}

output = synthetic_simulation(
    coeffs = coeffs, 
    nIter = 1e5, 
    maxHP = 100, 
    rPT = rPT, 
    rSLm = rSLm
)
# Out:
# Total 441 iterations will be held.
# 441it [11:27,  1.56s/it]

# %%
sr_test = get_sharpe_grid(output, rPT, rSLm)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(sr_test)
plt.title(f"Apple(AAPL) Synthetic Backtesting\nforecast = {coeffs['forecast'] : .4f} | half-life = {coeffs['hl'] : .4f}  | sigma = {coeffs['sigma'] : .1f}")
plt.xlabel("Profit taking")
plt.ylabel("Stop loss")
plt.grid(False)
plt.show()

# %%
#sr_test.to_csv('apple_synthetic_backtesting.csv')

# %%
start_date = '2020-01-01'
end_date = '2024-01-01'

goss = yf.download('GOSS', start = start_date, end = end_date)
goss.Close.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2020-01-02    15.40
# 2020-01-03    15.37
# 2020-01-06    15.10
# 2020-01-07    14.68
# 2020-01-08    14.34
# Name: Close, dtype: float64

# %%
params = get_OU_params(goss.Close)

# %%
print(f"expected phi : {params['phi'] : .4f}")
print(f"expected forecast : {params['forecast'] : .4f}")
print(f"sigma : {params['sigma'] : .4f}")
print(f"half life : {params['half life'] : .4f}")
# Out:
# expected phi :  0.9990
# expected forecast :  1.7759
# sigma :  0.0668
# half life :  725.3125

# %%
rPT = rSLm = np.linspace(0, 10, 21)
coeffs = {'forecast' : params['forecast'], 'hl' : params['half life'], 'sigma' : 1}

output = synthetic_simulation(
    coeffs = coeffs, 
    nIter = 1e5, 
    maxHP = 100, 
    rPT = rPT, 
    rSLm = rSLm
)
# Out:
# Total 441 iterations will be held.
# 441it [11:16,  1.53s/it]

# %%
sr_test = get_sharpe_grid(output, rPT, rSLm)

# %%
sns.heatmap(sr_test)
plt.title(f"GOSS Synthetic Backtesting\nforecast = {coeffs['forecast'] : .4f} | half-life = {coeffs['hl'] : .4f}  | sigma = {coeffs['sigma'] : .1f}")
plt.xlabel("Profit taking")
plt.ylabel("Stop loss")
plt.grid(False)
plt.show()

# %%
start_date = '2020-01-01'
end_date = '2024-01-01'

nike = yf.download('NKE', start = start_date, end = end_date)
nike.Close.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2020-01-02    102.199997
# 2020-01-03    101.919998
# 2020-01-06    101.830002
# 2020-01-07    101.779999
# 2020-01-08    101.550003
# Name: Close, dtype: float64

# %%
params = get_OU_params(nike.Close)

# %%
print(f"expected phi : {params['phi'] : .4f}")
print(f"expected forecast : {params['forecast'] : .4f}")
print(f"sigma : {params['sigma'] : .4f}")
print(f"half life : {params['half life'] : .4f}")
# Out:
# expected phi :  0.9930
# expected forecast :  4.7823
# sigma :  0.0222
# half life :  98.0809

# %%
rPT = rSLm = np.linspace(0, 10, 21)
coeffs = {'forecast' : params['forecast'], 'hl' : params['half life'], 'sigma' : 1}

output = synthetic_simulation(
    coeffs = coeffs, 
    nIter = 1e5, 
    maxHP = 100, 
    rPT = rPT, 
    rSLm = rSLm
)
# Out:
# Total 441 iterations will be held.
# 441it [11:40,  1.59s/it]

# %%
sr_test = get_sharpe_grid(output, rPT, rSLm)

# %%
sns.heatmap(sr_test)
plt.title(f"NIKE(NKE) Synthetic Backtesting\nforecast = {coeffs['forecast'] : .4f} | half-life = {coeffs['hl'] : .4f}  | sigma = {coeffs['sigma'] : .1f}")
plt.xlabel("Profit taking")
plt.ylabel("Stop loss")
plt.grid(False)
plt.show()
