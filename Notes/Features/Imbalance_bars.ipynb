# %%
from FinancialMachineLearning.barsampling.core import *
import matplotlib.pyplot as plt

# %%
import os
os.chdir('..')
os.chdir('..')
os.getcwd()
# Out:
# '/Users/junghunlee/Desktop/Pycharm/FinancialMachineLearning'

# %%
bar = ImbalanceBarFeatures('./Data/IVEfuture.csv')

# %% [markdown]
# #### Tick imbalance bar

# %%
tick_imbalance,_ = bar.const_tick_imbalance_bar(expected_imbalance_window = 200, exp_num_ticks_init = 300)
tick_imbalance
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#                date_time  tick_num     open      high       low   close  \
# 0    2009-09-28 10:00:15       300   50.790   51.2100   50.7100   51.21
# 1    2009-09-28 10:02:52       362   51.210   51.2600   51.2000   51.26
# 2    2009-09-28 10:31:45       676   51.250   51.3500   51.1873   51.35
# 3    2009-09-28 11:22:58      1018   51.350   51.3800   51.2700   51.35
# 4    2009-09-29 11:35:21      3860   51.340   51.9600   51.3200   51.56
# ...                  ...       ...      ...       ...       ...     ...
# 7449 2023-09-06 13:44:11  10921685  162.355  162.6000  159.9600  160.32
# 7450 2023-09-07 09:42:20  10922386  160.330  160.9400  160.2301  160.57
# 7451 2023-09-07 14:29:25  10923591  160.570  160.9200  160.2292  160.57
# 7452 2023-09-08 11:23:11  10925299  160.570  161.2900  160.4400  161.12
# 7453 2023-09-08 12:26:55  10925615  161.120  161.2096  160.8463  161.03
#
# ...

# %%
tick_imbalance.close.plot(grid = False, figsize = (10, 4))
plt.title('Tick Imbalance Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Tick Imbalance Bar')

# %% [markdown]
# #### Volume imbalance bar

# %%
volume_imbalance,_ = bar.const_volume_imbalance_bar(expected_imbalance_window = 50, exp_num_ticks_init = 100)
volume_imbalance
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#               date_time  tick_num     open     high      low     close  \
# 0   2009-09-28 09:54:43       226   50.790   51.150   50.710   51.1400
# 1   2009-09-28 10:23:41       580   51.140   51.290   51.080   51.2500
# 2   2009-09-28 11:51:43      1205   51.260   51.436   51.230   51.4300
# 3   2009-09-28 14:27:50      2209   51.430   51.600   51.406   51.4900
# 4   2009-10-01 16:16:36     10768   51.490   51.960   49.780   50.3166
# ..                  ...       ...      ...      ...      ...       ...
# 149 2020-02-25 15:27:11   7403448  122.790  123.510  122.340  122.7401
# 150 2020-02-26 09:30:00   7404388  122.790  123.250  122.250  123.2500
# 151 2020-02-26 16:10:05   7410250  123.175  124.170  121.440  121.4738
# 152 2020-02-27 10:02:22   7411185  121.490  121.490  118.630  119.2520
# 153 2020-03-25 16:16:17   7612446  118.780  121.600   81.700   92.1200
#
# ...

# %%
volume_imbalance.close.plot(grid = False, figsize = (10, 4))
plt.title('Volume Imbalance Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Volume Imbalance Bar')

# %% [markdown]
# #### Dollar imbalance bar

# %%
dollar_imbalance,_ = bar.const_dollar_imbalance_bar(expected_imbalance_window = 50, exp_num_ticks_init = 100)
dollar_imbalance
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#               date_time  tick_num    open     high      low     close  \
# 0   2009-09-28 09:54:43       226   50.79   51.150   50.710   51.1400
# 1   2009-09-28 10:23:41       580   51.14   51.290   51.080   51.2500
# 2   2009-09-28 11:51:43      1205   51.26   51.436   51.230   51.4300
# 3   2009-09-28 14:27:50      2209   51.43   51.600   51.406   51.4900
# 4   2009-10-01 16:16:36     10768   51.49   51.960   49.780   50.3166
# ..                  ...       ...     ...      ...      ...       ...
# 335 2023-03-17 10:32:53  10703410  130.63  163.430   81.700  145.6200
# 336 2023-03-17 11:45:47  10704162  145.62  145.690  144.980  145.2068
# 337 2023-03-17 16:00:00  10705605  145.21  146.060  144.800  145.3500
# 338 2023-03-28 11:29:43  10722249  145.42  149.250  143.350  146.7500
# 339 2023-03-28 12:21:21  10722400  146.77  146.910  146.590  146.6000
#
# ...

# %%
dollar_imbalance.close.plot(grid = False, figsize = (10, 4))
plt.title('Dollar Imbalance Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Dollar Imbalance Bar')
