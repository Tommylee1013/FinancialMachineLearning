# %%
from FinancialMachineLearning.barsampling.core import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.chdir('..')
os.chdir('..')
os.getcwd()
# Out:
# '/Users/junghunlee/Desktop/Pycharm/FinancialMachineLearning'

# %%
bar = RunBarFeatures('./Data/IVEfuture.csv')

# %% [markdown]
# #### Tick run bar

# %%
tick_run,_ = bar.const_tick_run_bar(expected_imbalance_window = 200, exp_num_ticks_init = 300)
tick_run
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#                 date_time  tick_num      open     high       low   close  \
# 0     2009-09-28 10:33:32       713   50.7900   51.380   50.7100   51.34
# 1     2009-09-28 11:22:56      1002   51.3400   51.370   51.2700   51.35
# 2     2009-09-28 12:04:34      1260   51.3500   51.440   51.3200   51.44
# 3     2009-09-28 13:47:21      1648   51.4400   51.600   51.4104   51.57
# 4     2009-09-28 14:18:08      1984   51.5700   51.570   51.4100   51.44
# ...                   ...       ...       ...      ...       ...     ...
# 37119 2023-09-13 15:50:38  10928967  161.4071  161.480  160.8300  161.18
# 37120 2023-09-14 10:12:19  10929278  161.2200  162.500  161.1700  162.17
# 37121 2023-09-14 11:44:23  10929559  162.1400  162.740  162.0700  162.57
# 37122 2023-09-14 14:44:34  10929881  162.5700  163.090  162.5400  163.06
# 37123 2023-09-14 15:59:45  10930174  163.0879  163.215  162.8900  162.97
#
#        volume  cum_buy_volume  cum_ticks  cum_dollar_value
# 0      219648          145523        713      1.124199e+07
# 1       71226           40593        289      3.655622e+06
# 2      108780           70210        258      5.589472e+06
# 3       85389           42315        388      4.395967e+06
# 4      104574           43145        336      5.380183e+06
# ...       ...             ...        ...               ...
# 37119   50594           28311        260      8.153278e+06
# 37120  220343           36126        311      3.557055e+07
# 37121   39694           24359        281      6.450589e+06
# 37122   90653           55288        322      1.475454e+07
# 37123   91634           61519        293      1.493903e+07
#
# [37124 rows x 10 columns]

# %%
tick_run.close.plot(grid = False, figsize = (10, 4))
plt.title('Tick Run Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Tick Run Bar')

# %% [markdown]
# #### Volume run bar

# %%
volume_run,_ = bar.const_volume_run_bar(expected_imbalance_window = 50, exp_num_ticks_init = 100)
volume_run
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#                 date_time  tick_num     open      high       low     close  \
# 0     2009-09-28 09:55:26       255   50.790   51.1500   50.7100   51.1400
# 1     2009-09-28 10:09:02       423   51.140   51.2800   51.0800   51.2700
# 2     2009-09-28 10:20:14       535   51.270   51.2900   51.2080   51.2300
# 3     2009-09-28 10:31:45       672   51.230   51.3500   51.1873   51.3500
# 4     2009-09-28 10:44:48       800   51.350   51.3800   51.3100   51.3200
# ...                   ...       ...      ...       ...       ...       ...
# 60991 2023-09-08 12:24:59  10925583  161.050  161.1355  160.8463  161.1100
# 60992 2023-09-08 13:30:26  10925781  161.110  161.1100  160.6900  160.8700
# 60993 2023-09-08 14:11:12  10925861  160.885  161.0599  160.8100  160.9500
# 60994 2023-09-08 14:45:19  10925973  160.910  160.9100  160.6800  160.7700
# 60995 2023-09-08 16:08:54  10926182  160.750  160.9355  160.5600  160.9355
#
#        volume  cum_buy_volume  cum_ticks  cum_dollar_value
# 0       82595           58041        255      4.217550e+06
# 1       50664           34434        168      2.595231e+06
# 2       36205           25548        112      1.855865e+06
# 3       40384           22000        137      2.069986e+06
# 4       32662           15584        128      1.676950e+06
# ...       ...             ...        ...               ...
# 60991   27871            7516        107      4.486951e+06
# 60992   28621           11983        198      4.606175e+06
# 60993   16720            7405         80      2.691396e+06
# 60994   44408            7905        112      7.139493e+06
# 60995  378991          352477        209      6.098474e+07
#
# [60996 rows x 10 columns]

# %%
volume_run.close.plot(grid = False, figsize = (10, 4))
plt.title('Volume Run Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Volume Run Bar')

# %% [markdown]
# #### Dollar run bar

# %%
dollar_run,_ = bar.const_dollar_run_bar(expected_imbalance_window = 50, exp_num_ticks_init = 100)
dollar_run
# Out:
# Reading data in batches:
# Batch number: 0
# Batch number: 1
# Returning bars
#                 date_time  tick_num      open      high       low     close  \
# 0     2009-09-28 09:55:26       255   50.7900   51.1500   50.7100   51.1400
# 1     2009-09-28 10:09:02       423   51.1400   51.2800   51.0800   51.2700
# 2     2009-09-28 10:20:14       535   51.2700   51.2900   51.2080   51.2300
# 3     2009-09-28 10:31:45       672   51.2300   51.3500   51.1873   51.3500
# 4     2009-09-28 10:44:48       800   51.3500   51.3800   51.3100   51.3200
# ...                   ...       ...       ...       ...       ...       ...
# 61114 2023-09-08 12:24:59  10925582  161.0500  161.1355  160.8463  161.1100
# 61115 2023-09-08 13:21:03  10925761  161.1100  161.1100  160.6900  160.9900
# 61116 2023-09-08 14:09:42  10925857  160.9900  161.0599  160.8100  161.0012
# 61117 2023-09-08 14:45:19  10925973  161.0047  161.0047  160.6800  160.7700
# 61118 2023-09-08 16:08:54  10926182  160.7500  160.9355  160.5600  160.9355
#
#        volume  cum_buy_volume  cum_ticks  cum_dollar_value
# 0       82595           58041        255      4.217550e+06
# 1       50664           34434        168      2.595231e+06
# 2       36205           25548        112      1.855865e+06
# 3       40384           22000        137      2.069986e+06
# 4       32662           15584        128      1.676950e+06
# ...       ...             ...        ...               ...
# 61114   27521            7516        106      4.430562e+06
# 61115   25472            9988        179      4.099376e+06
# 61116   19494            9227         96      3.137880e+06
# 61117   45133            8078        116      7.256196e+06
# 61118  378991          352477        209      6.098474e+07
#
# [61119 rows x 10 columns]

# %%
dollar_run.close.plot(grid = False, figsize = (10, 4))
plt.title('Dollar Run Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Dollar Run Bar')
