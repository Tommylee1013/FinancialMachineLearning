# %%
from FinancialMachineLearning.barsampling.core import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /Users/junghunlee/Desktop/Pycharm/FinancialMachineLearning/FinancialMachineLearning/multiprocess/fast_ewma.py:5: NumbaDeprecationWarning: The keyword argument 'nopython=False' was supplied. From Numba 0.59.0 the default is being changed to True and use of 'nopython=False' will raise a warning as the argument will have no effect. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit((float64[:], int64), nopython = False, nogil = True)

# %%
import os
os.chdir('..')
os.chdir('..')
os.getcwd()
# Out:
# '/Users/junghunlee/Desktop/Pycharm/FinancialMachineLearning'

# %%
bar = RunBarFeatures('./Data/raw_tick_data.csv')

# %% [markdown]
# #### Tick run bar

# %%
tick_run,_ = bar.const_tick_run_bar(expected_imbalance_window = 200, exp_num_ticks_init = 300)
tick_run
# Out:
# Reading data in batches:
# Batch number: 0
# Returning bars
#                date_time  tick_num     open      high       low     close  \
# 0    2009-09-28 13:16:46       723   50.790   51.5100   50.7100   51.4536
# 1    2009-09-28 15:30:02      1047   51.470   51.6000   51.3936   51.4800
# 2    2009-09-29 10:05:00      1337   51.480   51.9600   51.3790   51.6300
# 3    2009-09-29 11:53:04      1640   51.580   51.8075   51.3700   51.4320
# 4    2009-09-29 15:30:24      1929   51.450   51.7700   51.4500   51.5900
# ...                  ...       ...      ...       ...       ...       ...
# 4786 2018-10-04 13:50:28   1414772  116.360  116.4200  115.9270  116.0165
# 4787 2018-10-04 18:30:00   1415096  116.019  116.6058  115.8800  116.5800
# 4788 2018-10-05 11:11:13   1415376  116.650  116.8800  116.3800  116.3800
# 4789 2018-10-05 13:01:40   1415652  116.380  116.5099  115.9200  115.9700
# 4790 2018-10-05 15:29:57   1415974  115.960  116.2200  115.7937  116.1506
#
# ...

# %%
tick_run.close.plot(grid = False, figsize = (10, 4))
plt.title('Tick Run Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Tick Run Bar')

# %% [markdown]
# #### Volume run bar

# %%
volume_run,_ = bar.const_volume_run_bar(expected_imbalance_window = 50, exp_num_ticks_init = 100)
volume_run
# Out:
# Reading data in batches:
# Batch number: 0
# Returning bars
#                date_time  tick_num      open      high       low     close  \
# 0    2009-09-28 10:09:05       246   50.7900   51.2900   50.7100   51.2800
# 1    2009-09-28 10:26:10       324   51.2900   51.2900   51.1873   51.2550
# 2    2009-09-28 11:07:36       458   51.2510   51.3800   51.2300   51.3400
# 3    2009-09-28 11:46:33       573   51.3400   51.4360   51.3000   51.4000
# 4    2009-09-28 12:03:43       619   51.4000   51.4400   51.4000   51.4300
# ...                  ...       ...       ...       ...       ...       ...
# 7745 2018-10-03 14:54:45   1413735  116.9800  117.0050  116.5200  116.5350
# 7746 2018-10-03 15:17:26   1413801  116.5134  116.6700  116.5134  116.5973
# 7747 2018-10-03 15:35:56   1413876  116.5700  116.5800  116.4400  116.5426
# 7748 2018-10-03 16:00:00   1413993  116.5500  116.6653  116.5250  116.6200
# 7749 2018-10-04 09:53:51   1414082  116.6200  116.8500  116.4300  116.8100
#
# ...

# %%
volume_run.close.plot(grid = False, figsize = (10, 4))
plt.title('Volume Run Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Volume Run Bar')

# %% [markdown]
# #### Dollar run bar

# %%
dollar_run,_ = bar.const_dollar_run_bar(expected_imbalance_window = 50, exp_num_ticks_init = 100)
dollar_run
# Out:
# Reading data in batches:
# Batch number: 0
# Returning bars
#                date_time  tick_num      open      high       low     close  \
# 0    2009-09-28 10:09:05       246   50.7900   51.2900   50.7100   51.2800
# 1    2009-09-28 10:26:10       324   51.2900   51.2900   51.1873   51.2550
# 2    2009-09-28 11:07:36       458   51.2510   51.3800   51.2300   51.3400
# 3    2009-09-28 11:46:33       573   51.3400   51.4360   51.3000   51.4000
# 4    2009-09-28 12:03:43       619   51.4000   51.4400   51.4000   51.4300
# ...                  ...       ...       ...       ...       ...       ...
# 7824 2018-10-03 14:40:37   1413706  117.0490  117.0551  116.7030  116.7100
# 7825 2018-10-03 15:17:52   1413810  116.7134  116.7134  116.5134  116.5550
# 7826 2018-10-03 15:36:39   1413882  116.5500  116.5976  116.4400  116.5939
# 7827 2018-10-04 09:35:56   1414014  116.5800  116.6653  116.4300  116.5500
# 7828 2018-10-04 09:53:51   1414082  116.6100  116.8500  116.6100  116.8100
#
# ...

# %%
dollar_run.close.plot(grid = False, figsize = (10, 4))
plt.title('Dollar Run Bar', fontfamily = 'Serif', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Dollar Run Bar')
